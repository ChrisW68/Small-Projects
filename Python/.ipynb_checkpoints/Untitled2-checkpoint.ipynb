# %%
import os
os.listdir()
# Out:
# ['.idea',
#  '.ipynb_checkpoints',
#  'data.json',
#  'Dictionary-App.py.py',
#  'exercises',
#  'Sample-Files',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Testing.ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb']

# %%
import pandas

# %%
df1=pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2=pandas.read_json("supermarkets.json")
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df3=pandas.read_excel("supermarkes.xlsx",sheetname=[0])
df3
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-491936ce6b8b> in <module>()
# ----> 1 df3=pandas.read_excel("supermarkes.xlsx",sheetname=[0])
#       2 df3
#
# c:\users\chris\appdata\local\programs\python\python36\lib\site-packages\pandas\io\excel.py in read_excel(io, sheetname, header, skiprows, skip_footer, index_col, names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, has_index_names, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     201
#     202     if not isinstance(io, ExcelFile):
# --> 203         io = ExcelFile(io, engine=engine)
#     204
#     205     return io._parse_excel(
#
# c:\users\chris\appdata\local\programs\python\python36\lib\site-packages\pandas\io\excel.py in __init__(self, io, **kwds)
#     258             self.book = xlrd.open_workbook(file_contents=data)
# ...

# %%
df3=pandas.read_excel("supermarkets.xlsx",sheetname=[0])
df3
# Out:
# OrderedDict([(0,
#                  ID          Address           City             State Country  \
#               0   1     3666 21st St  San Francisco          CA 94114     USA
#               1   2   735 Dolores St  San Francisco          CA 94119     USA
#               2   3      332 Hill St  San Francisco  California 94114     USA
#               3   4     3995 23rd St  San Francisco          CA 94114     USA
#               4   5  1056 Sanchez St  San Francisco        California     USA
#               5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                 Supermarket Name  Number of Employees
#               0          Madeira                    8
#               1      Bready Shop                   15
#               2      Super River                   25
#               3       Ben's Shop                   10
#               4          Sanchez                   12
#               5       Richvalley                   20  )])

# %%
df4=pandas.read_csv("supermarkets_commas.txt")
df4
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-56b3cf244571> in <module>()
# ----> 1 df4=pandas.read_csv("supermarkets_commas.txt")
#       2 df4
#
# ...

# %%
df4=pandas.read_csv("supermarkets_comas.txt")
df4
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-42e5fbbbe676> in <module>()
# ----> 1 df4=pandas.read_csv("supermarkets_comas.txt")
#       2 df4
#
# ...

# %%
df4=pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets_semi-colons.txt",sep=";")
df5
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-4635b13f26a4> in <module>()
# ----> 1 df5=pandas.read_csv("supermarkets_semi-colons.txt",sep=";")
#       2 df5
#
# ...

# %%
df5=pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6=pandas.read_csv("http://pythonhow.com/supermarkets.csv")
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6.set_index("Address")
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df6=df6.set_index("Address")

# %%
df6
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df6.loc["332 Hill St":"551 Alvarado St","Name":"ID"]
# Out:
# Empty DataFrame
# Columns: []
# Index: [332 Hill St, 3995 23rd St, 1056 Sanchez St, 551 Alvarado St]

# %%
df6.loc["332 Hill St":"551 Alvarado St","Country":"ID"]
